# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoM1randa/am-t4-s1a2026/blob/main/Aula2403_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=2
b=3
print('A soma é:', a+b)
# Out:
# A soma é: 5

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print('A multiplicação é:', c*d)
# Out:
# A multiplicação é: 20

# %% [markdown]
# ## Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a,b,c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Numero sem raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1,x2

# %% [markdown]
# ## Testes de Função Matemática

# %%
eq = equacao2grau(1,-3,2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random
for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  eq += equacao2grau(a, b, c)

# %%
print(eq)
# Out:
# (2.0, 1.0, 0.10208423834364044, 4.89791576165636, -0.42264973081037427, -1.5773502691896255, -0.3062257748298549, 1.306225774829855, 'Numero sem raiz', -23, 'Numero sem raiz', -107, -0.0, 0.5, -1.3027756377319948, 2.302775637731995, -0.20871215252208009, -4.7912878474779195, -1.5564659966250536, 1.1564659966250537, 3.5413812651491097, -2.5413812651491097)
