# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoM1randa/am-t4-s1a2026/blob/main/NeuralizadorCelsus0424.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline | Anomalias e Normalização [Fase 1 - census_data]

# %% [markdown]
# ## Importar dados do Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Bibliotecas de Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
